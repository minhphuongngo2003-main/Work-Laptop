# %%
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
from vnstock import Vnstock
import pandas as pd
import pandas_datareader.data as web

# %%
stock = Vnstock().stock(symbol='ACB', source='VCI')  

df = stock.quote.history (start = '2024-01-01', end = '2025-01-01', interval = '1D')

print (df)

df.to_excel ('gia_lich_su_ACB.xlsx', index = False)
print("Đã lưu dữ liệu vào file ")
# Out:
#           time   open   high    low  close    volume
# 0   2024-01-02  16.81  17.37  16.81  17.16  13896933
# 1   2024-01-03  17.19  17.55  17.02  17.55   9817807
# 2   2024-01-04  17.69  18.00  17.62  17.76  23605373
# 3   2024-01-05  17.76  17.86  17.58  17.86   9282598
# 4   2024-01-08  18.04  18.07  17.69  17.79  12398885
# ..         ...    ...    ...    ...    ...       ...
# 245 2024-12-25  20.89  21.39  20.85  21.26   9518178
# 246 2024-12-26  21.26  21.35  21.22  21.35   5583577
# 247 2024-12-27  21.39  21.47  21.31  21.35   7694895
# 248 2024-12-30  21.18  21.43  21.18  21.22   5004572
# 249 2024-12-31  21.22  21.56  21.18  21.56   8844727
#
# [250 rows x 6 columns]
# Đã lưu dữ liệu vào file

# %%
from vnstock import Company
company = Company(symbol = 'FPT', source = 'TCBS')
company.overview()
# Out:
#   symbol exchange  ... industry_id industry_id_v2
# 0    FPT     HOSE  ...         310           9537
#
# [1 rows x 18 columns]

# %%
company.shareholders()
# Out:
#                            share_holder  share_own_percent
# 0                       Truong Gia Binh             0.0689
# 1  State Capital Investment Corporation             0.0567
# 2                        BUI QUANG NGOC             0.0148
# 3                Truong Thi Thanh Thanh             0.0147
# 4                       Hoang Minh Chau             0.0141
# 5                    Phan Ngo Tong Hung             0.0134
# 6                      Nguyen Thanh Nam             0.0094
# 7                            Do Cao Bao             0.0093
# 8                         Le Quang Tien             0.0063
# 9                                 Other             0.2247

# %%
company.officers (filter_by = 'working')
# Out:
#               officer_name  ... officer_own_percent
# 1          Truong Gia Binh  ...              0.0689
# 0          Truong Gia Binh  ...              0.0689
# 2           BUI QUANG NGOC  ...              0.0148
# 3   Truong Thi Thanh Thanh  ...              0.0147
# 5          Hoang Minh Chau  ...              0.0141
# 6          Hoang Minh Chau  ...              0.0141
# 7       Phan Ngo Tong Hung  ...              0.0134
# 11        Nguyen Thanh Nam  ...              0.0094
# 4               Do Cao Bao  ...              0.0093
# 15           Le Quang Tien  ...              0.0063
# 13        Duong Dung Trieu  ...              0.0044
# 9        Nguyen The Phuong  ...              0.0036
# 8        Nguyen The Phuong  ...              0.0036
# 10         Nguyen Van Khoa  ...              0.0032
# 18       Nguyen Khac Thanh  ...              0.0024
# 12          Hoang Viet Anh  ...              0.0023
# 16        Nguyen Khai Hoan  ...              0.0017
# ...

# %%
company. subsidiaries()
# Out:
#                            sub_company_name  sub_own_percent
# 0            FPT Investment Company Limited            1.000
# 1               FPT Digital Company Limited            1.000
# 2                    FPT IS Company Limited            1.000
# 3           FPT Smart Cloud Company Limited            1.000
# 4             FPT Education Company Limited            1.000
# 5              FPT Software Company Limited            1.000
# 6                 FPT Media Company Limited            1.000
# 7            Fpi Investment Company Limited            1.000
# 8            Synnex FPT Joint Stock Company            0.480
# 9    FPT Digital Retail Joint Stock Company            0.465
# 10                              FPT Telecom            0.457
# 11    HOMA Technologies Joint Stock Company            0.304
# 12  FPT Fund Management Joint Stock Company            0.250
# 13   FPT Online Service Joint Stock Company            0.239
# ...

# %%
company.events()
# Out:
#      rsi  ...                                         event_desc
# 0   66.9  ...           FPT - Financial Statement Quarter 2/2025
# 1   66.9  ...  FPT - Financial Statement Quarter 2/2025 (hold...
# 2   67.4  ...  FPT Corporation (FPT) issues bonus shares:\r E...
# 3   48.4  ...  FPT Corporation (FPT) lists additional shares:...
# 4   48.5  ...  FPT Corporation (FPT) pays cash dividend 2024-...
# 5   51.8  ...  - Name of person/ corporation that conducts th...
# 6   51.8  ...  - Name of person/ corporation that conducts th...
# 7   51.8  ...  - Name of person/ corporation that conducts th...
# 8   51.8  ...  - Name of person/ corporation that conducts th...
# 9   51.8  ...  - Name of person/ corporation that conducts th...
# 10  51.8  ...  - Name of person/ corporation that conducts th...
# 11  51.8  ...  - Name of person/ corporation that conducts th...
# 12  51.8  ...  - Name of person/ corporation that conducts th...
# ...

# %%
company.news()
# Out:
#      rsi    rs  ...  source         publish_date
# 0   41.5  15.0  ...    TCBS  2025-08-15 11:10:00
# 1   52.3  32.0  ...    TCBS  2025-08-13 07:54:00
# 2   47.8  33.0  ...    TCBS  2025-08-08 14:57:00
# 3   47.8  33.0  ...    TCBS  2025-08-08 11:05:00
# 4   47.8  33.0  ...    TCBS  2025-08-08 00:01:00
# 5   45.1  36.0  ...    TCBS  2025-07-31 14:54:17
# 6   45.1  36.0  ...    TCBS  2025-07-31 14:53:07
# 7   45.1  36.0  ...    TCBS  2025-07-31 14:51:59
# 8   63.7  40.0  ...    TCBS  2025-07-28 15:09:21
# 9   63.7  40.0  ...    TCBS  2025-07-28 15:08:44
# 10  69.4  50.0  ...    TCBS  2025-07-18 15:05:53
# 11  68.0  46.0  ...    TCBS  2025-07-17 18:28:00
# 12  67.4  58.0  ...    TCBS  2025-07-16 09:18:09
# 13  66.1  48.0  ...    TCBS  2025-07-11 10:24:00
# 14  63.6  49.0  ...    TCBS  2025-07-10 17:58:18
#
# [15 rows x 10 columns]

# %%
company.trading_stats()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 company.trading_stats()
#
# File c:\Users\phuongnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\vnstock\base.py:90, in BaseAdapter.__getattr__(self, name)
#      88 def __getattr__(self, name):
#      89     # Delegate attribute access to the provider
# ---> 90     return getattr(self._provider, name)
#
# AttributeError: 'Company' object has no attribute 'trading_stats'

# %%
company.dividends()
# Out:
#    exercise_date  cash_year  cash_dividend_percentage issue_method
# 0     2025-06-12       2024                      0.10         cash
# 1     2024-12-02       2024                      0.10         cash
# 2     2024-06-12       2023                      0.10         cash
# 3     2023-08-24       2023                      0.10         cash
# 4     2023-07-05       2022                      0.10         cash
# 5     2023-07-05       2023                      0.15        share
# 6     2022-08-24       2022                      0.10         cash
# 7     2022-06-13       2021                      0.10         cash
# 8     2022-06-13       2022                      0.20        share
# 9     2021-08-16       2021                      0.10         cash
# 10    2021-06-01       2020                      0.10         cash
# 11    2021-06-01       2021                      0.15        share
# 12    2020-08-17       2020                      0.10         cash
# ...

# %%
company.reports()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 company.reports()
#
# File c:\Users\phuongnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\vnstock\base.py:90, in BaseAdapter.__getattr__(self, name)
#      88 def __getattr__(self, name):
#      89     # Delegate attribute access to the provider
# ---> 90     return getattr(self._provider, name)
#
# AttributeError: 'Company' object has no attribute 'reports'

# %%
company.insider_deals()
# Out:
#    deal_announce_date     deal_method deal_action  deal_quantity  deal_price  \
# 0          2025-05-12  Cổ đông nội bộ         Mua         4948.0    101999.0
# 2          2025-05-12  Cổ đông nội bộ         Mua        72188.0    101999.0
# 3          2025-05-12  Cổ đông nội bộ         Mua        79296.0    101999.0
# 4          2025-05-12  Cổ đông nội bộ         Mua       340336.0    101999.0
# 5          2025-05-12  Cổ đông nội bộ         Mua       385556.0    101999.0
# 6          2025-05-12  Cổ đông nội bộ         Mua       853514.0    101999.0
# 7          2025-05-12  Cổ đông nội bộ         Mua      1045448.0    101999.0
# 1          2025-05-12  Cổ đông nội bộ         Mua        10204.0    101999.0
# 8          2025-02-14  Cổ đông nội bộ         Bán     -2000000.0    124934.0
# 9          2024-11-19  Cổ đông nội bộ         Bán       -60000.0    111314.0
# 14         2024-10-14  Cổ đông nội bộ         Mua       182203.0    117821.0
# ...

# %%
###############################################################################################################################################################################################################################################################

# %%
stock.listing.all_symbols()
# Out:
#      symbol                                         organ_name
# 0       YTC  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...
# 1       YEG                     Công ty Cổ phần Tập đoàn Yeah1
# 2       YBM     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
# 3       YBC      Công ty Cổ phần Xi măng và Khoáng sản Yên Bái
# 4       XPH                    Công ty Cổ phần Xà phòng Hà Nội
# ...     ...                                                ...
# 1713    AAS            Công ty Cổ phần Chứng khoán SmartInvest
# 1714    AAM                    Công ty Cổ Phần Thủy Sản MeKong
# 1715    AAH                           Công ty Cổ phần Hợp Nhất
# 1716    AAA                  Công ty Cổ phần Nhựa An Phát Xanh
# 1717    A32                                 Công ty Cổ phần 32
#
# [1718 rows x 2 columns]

# %%
stock.listing.symbols_by_industries()
# Out:
#      symbol                                         organ_name  \
# 0       F88                         Công ty Cổ phần Đầu tư F88
# 1       DVT  Trung tâm Đào tạo nghiệp vụ Giao thông vận tải...
# 2       AFX  Công ty Cổ phần Xuất Nhập khẩu Nông sản Thực p...
# 3       AGR               Công ty Cổ phần Chứng khoán AGRIBANK
# 4       ALT                   Công ty Cổ phần Văn hóa Tân Bình
# ...     ...                                                ...
# 1581    XMD                  Công ty Cổ phần Xuân Mai - Đạo Tú
# 1582    CQT            Công ty Cổ phần Xi măng Quán Triều VVMI
# 1583    XPH                    Công ty Cổ phần Xà phòng Hà Nội
# 1584    XHC                  Công ty Cổ phần Xuân Hòa Việt Nam
# 1585    YBM     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
#
#                             icb_name3                   icb_name2  \
# 0                   Dịch vụ tài chính           Dịch vụ tài chính
# 1          Tư vấn & Hỗ trợ Kinh doanh  Hàng & Dịch vụ Công nghiệp
# ...

# %%
stock.listing.symbols_by_group('VN30')
# Out:
# 0     ACB
# 1     BCM
# 2     BID
# 3     CTG
# 4     DGC
# 5     FPT
# 6     GAS
# 7     GVR
# 8     HDB
# 9     HPG
# 10    LPB
# 11    MBB
# 12    MSN
# 13    MWG
# 14    PLX
# 15    SAB
# 16    SHB
# 17    SSB
# 18    SSI
# 19    STB
# 20    TCB
# 21    TPB
# 22    VCB
# 23    VHM
# 24    VIB
# 25    VIC
# 26    VJC
# 27    VNM
# 28    VPB
# 29    VRE
# Name: symbol, dtype: object

# %%
####################################################################################################################################################################################################################################################################

# %%
from vnstock import Listing
listing = Listing (source = 'VCI')

## List => list.sort() or sorted(list)
## DataFrames => .sort_values ("column names", ascending = True / False)
listing.all_symbols().sort_values("symbol", ascending = True)
# Out:
#      symbol                                         organ_name
# 1717    A32                                 Công ty Cổ phần 32
# 1716    AAA                  Công ty Cổ phần Nhựa An Phát Xanh
# 1715    AAH                           Công ty Cổ phần Hợp Nhất
# 1714    AAM                    Công ty Cổ Phần Thủy Sản MeKong
# 1713    AAS            Công ty Cổ phần Chứng khoán SmartInvest
# ...     ...                                                ...
# 4       XPH                    Công ty Cổ phần Xà phòng Hà Nội
# 3       YBC      Công ty Cổ phần Xi măng và Khoáng sản Yên Bái
# 2       YBM     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
# 1       YEG                     Công ty Cổ phần Tập đoàn Yeah1
# 0       YTC  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...
#
# [1718 rows x 2 columns]

# %%
listing.symbols_by_exchange().sort_values("symbol", ascending = True)
# Out:
#          symbol  exchange   type                          organ_short_name  \
# 3006  41B5G3000       HNX     FU  5-year Government Bond    Futures 032026
# 3005  41BAG3000       HNX     FU  10-year Government Bond   Futures 032026
# 3004  41I1F7000  DELISTED     FU                          41I1F7000 - HĐTL
# 3003  41I1F8000       HNX     FU                 VN30 Index Futures 082025
# 3002  41I1G3000       HNX     FU                 VN30 Index Futures 032026
# ...         ...       ...    ...                                       ...
# 4           XPH     UPCOM  STOCK                           Xà phòng Hà Nội
# 3           YBC     UPCOM  STOCK             Xi măng và Khoáng sản Yên Bái
# 2           YBM       HSX  STOCK                     Khoáng sản CN Yên Bái
# 1           YEG       HSX  STOCK                            Tập đoàn Yeah1
# 0           YTC     UPCOM  STOCK                           XNK Y tế TP.HCM
#
# ...

# %%
listing.symbols_by_group ('VN30')
# Out:
# 0     ACB
# 1     BCM
# 2     BID
# 3     CTG
# 4     DGC
# 5     FPT
# 6     GAS
# 7     GVR
# 8     HDB
# 9     HPG
# 10    LPB
# 11    MBB
# 12    MSN
# 13    MWG
# 14    PLX
# 15    SAB
# 16    SHB
# 17    SSB
# 18    SSI
# 19    STB
# 20    TCB
# 21    TPB
# 22    VCB
# 23    VHM
# 24    VIB
# 25    VIC
# 26    VJC
# 27    VNM
# 28    VPB
# 29    VRE
# Name: symbol, dtype: object

# %%
listing.symbols_by_industries()
# Out:
#      symbol                                         organ_name  \
# 0       F88                         Công ty Cổ phần Đầu tư F88
# 1       DVT  Trung tâm Đào tạo nghiệp vụ Giao thông vận tải...
# 2       AFX  Công ty Cổ phần Xuất Nhập khẩu Nông sản Thực p...
# 3       AGR               Công ty Cổ phần Chứng khoán AGRIBANK
# 4       ALT                   Công ty Cổ phần Văn hóa Tân Bình
# ...     ...                                                ...
# 1581    XMD                  Công ty Cổ phần Xuân Mai - Đạo Tú
# 1582    CQT            Công ty Cổ phần Xi măng Quán Triều VVMI
# 1583    XPH                    Công ty Cổ phần Xà phòng Hà Nội
# 1584    XHC                  Công ty Cổ phần Xuân Hòa Việt Nam
# 1585    YBM     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
#
#                             icb_name3                   icb_name2  \
# 0                   Dịch vụ tài chính           Dịch vụ tài chính
# 1          Tư vấn & Hỗ trợ Kinh doanh  Hàng & Dịch vụ Công nghiệp
# ...

# %%
listing.industries_icb()
# Out:
#                                    icb_name  \
# 0                          Sản xuất Dầu khí
# 1    Thiết bị, Dịch vụ và Phân phối Dầu khí
# 2                                  Hóa chất
# 3                        Lâm nghiệp và Giấy
# 4                                  Kim loại
# ..                                      ...
# 150                              Viễn thông
# 151                      Tiện ích Cộng đồng
# 152                               Tài chính
# 153                               Ngân hàng
# 154                     Công nghệ Thông tin
#
#                                 en_icb_name icb_code  level
# 0                       Oil & Gas Producers     0530      3
# 1    Oil Equipment, Services & Distribution     0570      3
# 2                                 Chemicals     1350      3
# 3                          Forestry & Paper     1730      3
# 4                Industrial Metals & Mining     1750      3
# ..                                      ...      ...    ...
# ...

# %%
from vnstock.explorer.msn.listing import Listing
Listing().search_symbol_id ('USD')
# Out:
#                  symbol symbol_id exchange_name  exchange_code_mic  \
# 0                   USD    a2521h     NYSE ARCA               ARCX
# 1                   USD    aaa5bh     Australia               XASX
# 2   SPCRR2B10BCJPUSD.TR    cdmn6h                  INDX_DEFAULT-SP
# 3  SPCRR2B10BCJPUSD.NTR    cdmn3m                  INDX_DEFAULT-SP
# 4           WIIDNNTUU_T    bxztar                INDX_DEFAULT-FTSE
# 5              GPPS006U    blhasm                  INDX_24HRS-FTSE
# 6             AWE7EMG1U    bufsgh                  INDX_24HRS-FTSE
# 7              JIGBUS.A    caclvh    NYSEGlobal  INDX_DEFAULT-NYSE
# 8               FDCICUH    blbuww                  INDX_24HRS-FTSE
# 9              FGCICUHN    bxwl5r                INDX_DEFAULT-FTSE
#
#                                           short_name  \
# 0                             ProShares:Ult Semicond
# 1                           BetaShares US Dollar ETF
# 2  S&P Japan Between USD2 Billion and USD10 Billi...
# ...

# %%
from vnstock import Quote 
quote = Quote (symbol = 'FPT', source = 'VCI')
quote.history (start = '2024-01-01', end = '2025-01-01', interval = '1D')
# Out:
#           time    open    high     low   close   volume
# 0   2024-01-02   71.65   71.65   70.77   70.91  1717109
# 1   2024-01-03   70.69   71.36   70.54   71.21  1439581
# 2   2024-01-04   71.21   72.76   71.14   71.88  2978466
# 3   2024-01-05   71.95   72.10   71.36   72.02  1140908
# 4   2024-01-08   72.02   72.69   71.80   71.95  1446808
# ..         ...     ...     ...     ...     ...      ...
# 245 2024-12-25  129.85  130.37  129.68  130.02  2517969
# 246 2024-12-26  130.19  130.54  128.56  129.16  2238343
# 247 2024-12-27  128.90  129.25  128.21  128.99  2567003
# 248 2024-12-30  128.81  130.02  128.04  129.76  1986819
# 249 2024-12-31  129.93  132.69  129.59  131.49  3612655
#
# [250 rows x 6 columns]

# %%
quote.intraday()
# Out:
#                         time  price  volume match_type         id
# 0  2025-08-20 13:14:19+07:00   98.9    1500        Buy  349521918
# 1  2025-08-20 13:14:20+07:00   98.9     400        Buy  349521991
# 2  2025-08-20 13:14:20+07:00   98.8     800       Sell  349521957
# 3  2025-08-20 13:14:20+07:00   98.8     100       Sell  349521956
# 4  2025-08-20 13:14:20+07:00   98.8     500       Sell  349521955
# ..                       ...    ...     ...        ...        ...
# 95 2025-08-20 13:15:13+07:00   98.8    1400        Buy  349526806
# 96 2025-08-20 13:15:14+07:00   98.8     100        Buy  349526927
# 97 2025-08-20 13:15:15+07:00   98.7     400       Sell  349526950
# 98 2025-08-20 13:15:15+07:00   98.8     200        Buy  349526963
# 99 2025-08-20 13:15:16+07:00   98.8     600        Buy  349527060
#
# [100 rows x 5 columns]

# %%
####################################################################################################################################################################################################################################################################

# %%
from vnstock.explorer.msn.quote import Quote
quote = Quote (symbol_id = 'avyufr')
quote.history (start = '2020-01-01', end = '2024-12-31', interval = '1M')
# Out:
#          time        open     high         low    close
# 0  2020-01-31 -99999902.0  23226.0 -99999902.0  23222.0
# 1  2020-02-29     23250.0  23280.0     23200.0  23240.0
# 2  2020-03-31     23238.0  23650.0     23170.0  23616.0
# 5  2020-06-30     23280.0  23300.0     23185.0  23204.0
# 6  2020-07-31     23200.0  23212.0     23165.0  23170.0
# 7  2020-08-31     23170.0  23195.0     23165.0  23174.0
# 9  2020-10-31     23183.0  23206.0     23170.0  23180.0
# 10 2020-11-30     23177.0  23186.0     23130.0  23140.0
# 11 2020-12-31     23131.0  23177.0     23070.0  23070.0
# 14 2021-03-31     23010.0  23090.0     23010.0  23074.0
# 17 2021-06-30     23045.0  23052.0     22935.0  23014.0
# 18 2021-07-31     23015.0  23028.0     22950.0  22950.0
# 19 2021-08-31     22950.0  22965.0     22770.0  22775.0
# 21 2021-10-31     22759.0  22800.0     22740.0  22750.0
# 22 2021-11-30     22748.0  22757.0     22636.0  22688.0
# 23 2021-12-31     22685.0  23110.0     22685.0  22825.0
# ...

# %%
fx = Vnstock().fx (symbol = 'USDVND', source = 'MSN')
fx.quote.history (start = '2024-02-28', end = '2025-08-19')

# symbol: Mã cặp tiền tệ cần tra cứu. Hiện tại hàm hỗ trợ truy xuất dữ liệu trực tiếp cho các cặp tiền tệ sau:USDVND, JPYVND, AUDVND, CNYVND, KRWVND, USDJPY, USDEUR, USDCAD, USDCHF, USDCNY, USDKRW, USDSGD, USDHKD, USDTRY, USDINR, USDDKK, USDSEK, USDILS, USDRUB, USDMXN, USDZAR, EURUSD, EURVND, EURJPY, EURGBP, EURCHF, EURCAD, EURAUD, EURNZD, GBPJPY, GBPVND, GBPUSD, GBPAUD, GBPCHF, GBPNZD, GBPCAD, AUDUSD, NZDUSD.
# Out:
#           time     open     high      low    close
# 6   2024-03-07  24640.0  24705.0  24640.0  24680.0
# 7   2024-03-08  24675.0  24690.0  24615.0  24640.0
# 8   2024-03-11  24635.0  24660.0  24590.0  24635.0
# 9   2024-03-12  24640.0  24645.0  24615.0  24645.0
# 10  2024-03-13  24640.0  24680.0  24630.0  24675.0
# ..         ...      ...      ...      ...      ...
# 382 2025-08-13  26257.0  26285.0  26225.0  26265.0
# 383 2025-08-14  26274.0  26287.0  26230.0  26230.0
# 384 2025-08-15  26259.0  26280.0  26240.0  26240.0
# 385 2025-08-18  26270.0  26294.0  26243.0  26275.0
# 386 2025-08-19  26280.0  26312.0  26275.0  26290.0
#
# [365 rows x 5 columns]

# %%
crypto = Vnstock().crypto ( symbol = 'BTC', source = 'MSN')
crypto.quote.history ( start = '2024-02-28', end = '2025-08-10')

# symbol: Mã crypto bạn cần tra cứu. Hiện tại hỗ trợ các mã sau: BTC, ETH, USDT, USDC, BNB, BUSD, XRP, ADA, SOL, DOGE
# Out:
#           time          open  ...         close            volume
# 164 2024-03-09  1.762346e+09  ...  1.798205e+09  1558693455502734
# 165 2024-04-08  1.813923e+09  ...  1.826177e+09   558283406749239
# 166 2024-05-08  1.662949e+09  ...  1.641151e+09   682704285282511
# 167 2024-06-07  1.871469e+09  ...  1.862895e+09   664075146043981
# 168 2024-07-07  1.491720e+09  ...  1.535016e+09   542628520148359
# 169 2024-08-06  1.529928e+09  ...  1.421487e+09  2869517301266609
# 170 2024-09-05  1.512026e+09  ...  1.526275e+09   938005567252493
# 171 2024-10-05  1.599548e+09  ...  1.634113e+09   778926320324107
# 172 2024-11-04  1.824435e+09  ...  1.809816e+09   918012803945579
# 173 2024-12-04  2.523660e+09  ...  2.527545e+09  1765761326987263
# 174 2025-01-03  2.485792e+09  ...  2.550838e+09  1211339811817810
# 175 2025-02-02  2.696061e+09  ...  2.650069e+09   730811171966042
# 176 2025-03-04  2.481372e+09  ...  2.265937e+09  1844861632907919
# ...

# %%
index = Vnstock().world_index(symbol = 'INX', source = 'MSN')
index.quote.history(start = '2023-01-01', end = '2025-08-17')

#INX: S&P 500 Index
# DJI: Dow Jones Industrial Average
# COMP: Nasdaq Composite Index
# RUT: Russell 2000 Index
# NYA: NYSE Composite Index
# RUI: Russell 1000 Index
# RUA: Russell 3000 Index
# UKX: FTSE 100 Index
# DAX: DAX Index
# PX1: CAC 40 Index
# N225: Nikkei 225 Index
# 000001: Shanghai SE Composite Index
# HSI: Hang Seng Index
# SENSEX: S&P BSE Sensex Index
# ME00000000: S&P/BMV IPC
# Out:
#           time     open     high      low    close      volume
# 293 2024-03-05  5110.52  5114.54  5056.82  5078.65  2704129642
# 294 2024-03-06  5108.03  5127.97  5092.22  5104.76  2604927497
# 295 2024-03-07  5132.38  5165.62  5128.21  5157.36  2359269056
# 296 2024-03-08  5164.46  5189.26  5117.50  5123.69  2430070760
# 297 2024-03-11  5111.96  5124.66  5091.14  5117.94  2207490802
# ..         ...      ...      ...      ...      ...         ...
# 653 2025-08-11  6389.67  6407.25  6364.06  6373.45  2882117019
# 654 2025-08-12  6395.17  6446.55  6385.76  6445.76  2870584140
# 655 2025-08-13  6462.67  6480.28  6445.02  6466.58  3088354173
# 656 2025-08-14  6453.46  6473.92  6441.07  6468.54  2766449273
# 657 2025-08-15  6477.38  6481.34  6441.85  6449.80  3147834712
#
# [365 rows x 6 columns]

# %%
####################################################################################################################################################################################################################################################################

# %%
from vnstock import Finance
finance = Finance (symbol = 'HPG', source = 'VCI')
finance.income_statement (period = 'year', lang = 'vi')

# lang = 'vi' => vietnamese
# Out:
#      CP   Năm  ...  Cổ đông thiểu số  Cổ đông của Công ty mẹ
# 0   HPG  2024  ...       -1420214803          12021443836074
# 1   HPG  2023  ...      -34676019275           6835064334356
# 2   HPG  2022  ...      -39081499515           8483510554031
# 3   HPG  2021  ...       42811733838          34478143197460
# 4   HPG  2020  ...       55864004095          13450300052812
# 5   HPG  2019  ...       50805368355           7527442867874
# 6   HPG  2018  ...       27536495813           8573014210414
# 7   HPG  2017  ...        8084472201           8006672113847
# 8   HPG  2016  ...        4100726657           6602102000272
# 9   HPG  2015  ...       18919523530           3485462964249
# 10  HPG  2014  ...      105961744233           3144252845971
# 11  HPG  2013  ...       56247864896           1954187537873
#
# [12 rows x 28 columns]

# %%
finance.balance_sheet(period = 'year', lang = 'vi')
# Out:
#      CP   Năm  ...  Phải thu dài hạn khác (đồng)  Phải thu dài hạn (đồng)
# 0   HPG  2024  ...                  840594835822             923400123614
# 1   HPG  2023  ...                  781079548004            1880922130348
# 2   HPG  2022  ...                  792790894665             894484456379
# 3   HPG  2021  ...                  690833578689             809234947969
# 4   HPG  2020  ...                  209158308631             305165547431
# 5   HPG  2019  ...                   22807248984              27717594984
# 6   HPG  2018  ...                   22301804672              22301804672
# 7   HPG  2017  ...                   21810530536              21810530536
# 8   HPG  2016  ...                   15673189031              18173189031
# 9   HPG  2015  ...                   11485258954              16485258954
# 10  HPG  2014  ...                    9225561499               9225561499
# 11  HPG  2013  ...                  449759238679             449759238679
#
# ...

# %%
finance.cash_flow (period = 'quarter', lang= 'vi')
# Out:
#      CP  ...  Tiền và tương đương tiền cuối kỳ
# 0   HPG  ...                    10688024277258
# 1   HPG  ...                     7459035818129
# 2   HPG  ...                     6887646139852
# 3   HPG  ...                     8500998079280
# 4   HPG  ...                    13032037853283
# 5   HPG  ...                    12428888036237
# 6   HPG  ...                    12267401160884
# 7   HPG  ...                     9696669423876
# 8   HPG  ...                    13252855086239
# 9   HPG  ...                     7868451566326
# 10  HPG  ...                     8324588920227
# 11  HPG  ...                    11881408346665
# 12  HPG  ...                    20325198022112
# 13  HPG  ...                    19060014590301
# 14  HPG  ...                    22471375562130
# 15  HPG  ...                    13376486099355
# 16  HPG  ...                    14644183731657
# 17  HPG  ...                    14018629193714
# 18  HPG  ...                    13001001772526
# ...

# %%
finance.ratio (period = 'year', lang = 'vi')
# Out:
#    Meta           ... Chỉ tiêu định giá
#      CP   Năm Kỳ  ...         EPS (VND)    BVPS (VND)  EV/EBITDA
# 0   HPG  2024  5  ...       1879.451782  17878.673250  11.896202
# 1   HPG  2023  5  ...       1175.462809  17674.021829  12.655247
# 2   HPG  2022  5  ...       1458.954980  16510.905547  10.684917
# 3   HPG  2021  5  ...       7708.191146  20260.988787   2.634939
# 4   HPG  2020  5  ...       4059.508782  17828.554247   8.867266
# 5   HPG  2019  5  ...       2726.273383  17248.150713  14.534391
# 6   HPG  2018  5  ...       4036.435466  19066.741249  10.538536
# 7   HPG  2017  5  ...       5277.689635  21282.323720   7.704453
# 8   HPG  2016  5  ...       7832.836832  23425.269949   4.913458
# 9   HPG  2015  5  ...       4755.380608  19706.345060   7.652868
# 10  HPG  2014  5  ...       6524.589142  24477.659102   5.744011
# 11  HPG  2013  5  ...       4663.347394  22670.969643   8.359687
#
# [12 rows x 37 columns]

# %%
from vnstock.explorer.vci import Finance
fin = Finance (symbol = 'MWG', period = 'quarter')
fin._get_report (mode = 'raw')
# Out:
#    ticker  yearReport  lengthReport  ...         BSA49  CFB64             __typename
# 0     MWG        2025             2  ...  379627026598    0.0  CompanyFinancialRatio
# 1     MWG        2025             1  ...  395223532870    0.0  CompanyFinancialRatio
# 2     MWG        2024             4  ...  358454413877    0.0  CompanyFinancialRatio
# 3     MWG        2024             3  ...  290295051827    0.0  CompanyFinancialRatio
# 4     MWG        2024             2  ...  394567740029    0.0  CompanyFinancialRatio
# 5     MWG        2024             1  ...  427378020040    0.0  CompanyFinancialRatio
# 6     MWG        2023             4  ...  452067531470    0.0  CompanyFinancialRatio
# 7     MWG        2023             3  ...  577904496828    0.0  CompanyFinancialRatio
# 8     MWG        2023             2  ...  592185687837    0.0  CompanyFinancialRatio
# 9     MWG        2023             1  ...  640218535512    0.0  CompanyFinancialRatio
# ...

# %%
fin._get_ratio_dict()
# Out:
#               field_name                           name  ...   unit com_type_code
# 0                   BSA1          TỔNG TÀI SẢN NGẮN HẠN  ...     tỷ            BH
# 1                   BSA2       Tiền và tương đương tiền  ...     tỷ            BH
# 2                   BSA5  Giá trị thuần đầu tư ngắn hạn  ...     tỷ            BH
# 3                   BSA8             Các khoản phải thu  ...     tỷ            BH
# 4                  BSA15              Hàng tồn kho ròng  ...     tỷ            BH
# ..                   ...                            ...  ...    ...           ...
# 733                 ebit                 EBIT (Tỷ đồng)  ...     tỷ            NH
# 734             dividend             Tỷ suất cổ tức (%)  ...      %            NH
# 735                RTQ17         Vòng quay hàng tồn kho  ...  index            NH
# 736                  fae                 TSCĐ / Vốn CSH  ...  index            NH
# ...

# %%
####################################################################################################################################################################################################################################################################

# %%
from vnstock import Trading
trading.price_board (symbols_list = ['VIC'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 2
#       1 from vnstock import Trading
# ----> 2 trading = Trading (symbols_list = ['VIC','VCB','ACB','TCB','BID'])
#       3 trading.price_board ()
#
# TypeError: Trading.__init__() got an unexpected keyword argument 'symbols_list'

# %%
trading.price_board(symbols_list=['VCB','ACB','TCB','BID']).iloc[0].T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 trading.price_board(symbols_list=['VCB','ACB','TCB','BID']).iloc[0].T
#
# NameError: name 'trading' is not defined

# %%
####################################################################################################################################################################################################################################################################

# %%
from vnstock import Screener 
screener_df = Screener().stock (params = {"exchangeName": "HOSE, HNX, UPCOM"}, limit  =1700)
# Out:
# 2025-08-20 14:27:07 - vnstock.explorer.tcbs.screener - ERROR - Error fetching stock data: Failed to fetch data: 400 - Bad Request
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[94], line 2
#       1 from vnstock import Screener
# ----> 2 screener_df = Screener().stock (params = {"exchangeName": "HOSE, HNX, UPCOM"}, limit  =1700)
#
# File c:\Users\phuongnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\vnstock\api\screener.py:49, in Screener.stock(self, params, limit, id, lang)
#      47     params = {"exchangeName": "HOSE,HNX,UPCOM"}
#      48 # Delegate to underlying TCBS Screener
# ---> 49 return self.client.stock(params=params, limit=limit, id=id, lang=lang)
#
# File c:\Users\phuongnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\vnai\beam\quota.py:291, in _create_wrapper.<locals>.wrapper(*args, **kwargs)
#     289 error = None
# ...

# %%
####################################################################################################################################################################################################################################################################

# %%
from vnstock import Fund
fund = Fund()
fund.listing()
# Out:
# 2025-08-20 14:26:52 - vnstock.explorer.fmarket.fund - INFO - Total number of funds currently listed on Fmarket: 58
# 2025-08-20 14:26:52 - vnstock.explorer.fmarket.fund - INFO - Total number of funds currently listed on Fmarket: 58
#    short_name  ...   vsd_fee_id
# 0        DCDS  ...   VFMVF1N001
# 1      SSISCA  ...   SSISCAN001
# 2        MBVF  ...     MBVFN001
# 3       BVFED  ...    BVFEDN001
# 4    VCBF-BCF  ...  VCBFBCFN001
# 5    VCBF-MGF  ...  VCBFMGFN001
# 6       VESAF  ...    VESAFN002
# 7        DCDE  ...   VFMVF4N001
# 8      VCAMBF  ...   VCAMBFN001
# 9       MAGEF  ...    MAGEFN001
# 10       VEOF  ...     VEOFN003
# 11        ENF  ...      ENFN001
# 12   VCBF-TBF  ...  VCBFTBFN001
# 13       BVPF  ...     BVPFN001
# 14       VLGF  ...     VLGFN001
# 15     MAFEQI  ...       MAFEQI
# 16       VIBF  ...     VIBFN003
# 17     MAFBAL  ...       MAFBAL
# 18      VNDAF  ...    VNDAFN001
# 19   VCBF-FIF  ...  VCBFFIFN001
# 20       PVBF  ...     PVBFN001
# ...

# %%
fund.filter('DC')
# Out:
#    id shortName
# 0  40     VNDCF
# 1  67      DCIP
# 2  62    HDBOND
# 3  27      DCBF
# 4  25      DCDE
# 5  28      DCDS
# 6  29      DCAF

# %%
fund.details.nav_report ('DCBF')
# Out:
# 2025-08-20 14:28:56 - vnstock.explorer.fmarket.fund - INFO - Retrieving data for DCBF
#            date  nav_per_unit short_name
# 0    2017-01-06      13822.49       DCBF
# 1    2017-01-13      13882.79       DCBF
# 2    2017-01-20      13941.88       DCBF
# 3    2017-01-27      13965.99       DCBF
# 4    2017-02-03      13979.95       DCBF
# ..          ...           ...        ...
# 522  2025-08-01      28190.83       DCBF
# 523  2025-08-06      28204.48       DCBF
# 524  2025-08-08      28230.19       DCBF
# 525  2025-08-13      28238.34       DCBF
# 526  2025-08-15      28250.33       DCBF
#
# [527 rows x 3 columns]

# %%
fund.details.top_holding('SSISCA')
# Out:
# 2025-08-20 14:29:34 - vnstock.explorer.fmarket.fund - INFO - Retrieving data for SSISCA
#   stock_code                industry  ...  fundId short_name
# 0        MBB               Ngân hàng  ...      11     SSISCA
# 1        TCB               Ngân hàng  ...      11     SSISCA
# 2        CTG               Ngân hàng  ...      11     SSISCA
# 3        HPG       Vật liệu xây dựng  ...      11     SSISCA
# 4        STB               Ngân hàng  ...      11     SSISCA
# 5        FPT  Công nghệ và thông tin  ...      11     SSISCA
# 6        ACB               Ngân hàng  ...      11     SSISCA
# 7        VCB               Ngân hàng  ...      11     SSISCA
# 8        MWG                  Bán lẻ  ...      11     SSISCA
# 9        REE           Thiết bị điện  ...      11     SSISCA
#
# [10 rows x 7 columns]

# %%
fund.details.industry_holding ('SSISCA')
# Out:
# 2025-08-20 14:30:48 - vnstock.explorer.fmarket.fund - INFO - Retrieving data for SSISCA
#                     industry  net_asset_percent short_name
# 0                  Ngân hàng              37.26     SSISCA
# 1               Bất động sản              14.66     SSISCA
# 2          Vật liệu xây dựng               6.12     SSISCA
# 3     Công nghệ và thông tin               4.77     SSISCA
# 4                     Bán lẻ               4.34     SSISCA
# 5              Thiết bị điện               4.32     SSISCA
# 6           Sản xuất Phụ trợ               3.81     SSISCA
# 7   Sản xuất Nhựa - Hóa chất               3.33     SSISCA
# 8                Khai khoáng               2.95     SSISCA
# 9        Thực phẩm - Đồ uống               2.94     SSISCA
# 10                  Tiện ích               2.63     SSISCA
# 11         Vận tải - Kho bãi               2.15     SSISCA
# 12               Chứng khoán               1.90     SSISCA

# %%
fund.details.asset_holding ('SSISCA')
# Out:
# 2025-08-20 14:31:07 - vnstock.explorer.fmarket.fund - INFO - Retrieving data for SSISCA
#    asset_percent                asset_type short_name
# 0          91.17                  Cổ phiếu     SSISCA
# 1           8.83  Tiền và tương đương tiền     SSISCA

# %%
####################################################################################################################################################################################################################################################################

# %%
from vnstock.explorer.misc.gold_price import *
sjc_gold_price()
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\phuongnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
# ...

# %%
btmc_goldprice()
# Out:
#                                                 name  ...              time
# 20                         VÀNG MIẾNG SJC (Vàng SJC)  ...  20/08/2025 08:59
# 13                         VÀNG MIẾNG SJC (Vàng SJC)  ...  20/08/2025 14:21
# 6                          VÀNG MIẾNG SJC (Vàng SJC)  ...  20/08/2025 14:24
# 9              NHẪN TRÒN TRƠN (Vàng Rồng Thăng Long)  ...  20/08/2025 14:21
# 16             NHẪN TRÒN TRƠN (Vàng Rồng Thăng Long)  ...  20/08/2025 08:59
# 15            VÀNG MIẾNG VRTL (Vàng Rồng Thăng Long)  ...  20/08/2025 08:59
# 14       QUÀ MỪNG BẢN VỊ VÀNG (Quà Mừng Bản Vị Vàng)  ...  20/08/2025 08:59
# 1        QUÀ MỪNG BẢN VỊ VÀNG (Quà Mừng Bản Vị Vàng)  ...  20/08/2025 14:24
# 0             VÀNG MIẾNG VRTL (Vàng Rồng Thăng Long)  ...  20/08/2025 14:24
# 8        QUÀ MỪNG BẢN VỊ VÀNG (Quà Mừng Bản Vị Vàng)  ...  20/08/2025 14:21
# 7             VÀNG MIẾNG VRTL (Vàng Rồng Thăng Long)  ...  20/08/2025 14:21
# ...

# %%
from vnstock.explorer.misc.exchange_rate import *
vcb_exchange_rate(date = '2025-08-08')
# Out:
# Workbook contains no default style, apply openpyxl's default
#    currency_code        currency_name  ...       sell        date
# 2            AUD    AUSTRALIAN DOLLAR  ...  17,362.44  2025-08-08
# 3            CAD      CANADIAN DOLLAR  ...  19,392.58  2025-08-08
# 4            CHF          SWISS FRANC  ...  33,022.93  2025-08-08
# 5            CNY         CHINESE YUAN  ...   3,709.47  2025-08-08
# 6            DKK         DANISH KRONE  ...   4,174.37  2025-08-08
# 7            EUR                 EURO  ...  31,349.98  2025-08-08
# 8            GBP    UK POUND STERLING  ...  35,779.58  2025-08-08
# 9            HKD     HONG KONG DOLLAR  ...   3,404.08  2025-08-08
# 10           INR         INDIAN RUPEE  ...     310.48  2025-08-08
# 11           JPY         JAPANESE YEN  ...     182.79  2025-08-08
# 12           KRW           KOREAN WON  ...      19.69  2025-08-08
# 13           KWD        KUWAITI DINAR  ...  89,007.23  2025-08-08
# ...

# %%
####################################################################################################################################################################################################################################################################

# %%
ticker = 'MWG'

stock = Vnstock().stock(symbol=ticker, source='TCBS')  

df = stock.quote.history (start = '2024-01-01', end = '2025-08-01', interval = '1D')

print (df)

## df.viz.timeseries(): Does not work
# Out:
# 2025-08-20 15:22:30 - vnstock.common.data.data_explorer - INFO - TCBS không cung cấp thông tin danh sách. Dữ liệu tự động trả về từ VCI.
#           time   open   high    low  close    volume
# 0   2024-01-02  42.15  42.35  41.22  41.52   7143270
# 1   2024-01-03  41.47  42.50  41.08  42.25   6086184
# 2   2024-01-04  42.25  42.84  42.06  42.25   8519623
# 3   2024-01-05  42.25  43.13  42.06  42.89   9044887
# 4   2024-01-08  43.33  43.33  42.25  42.25   6215699
# ..         ...    ...    ...    ...    ...       ...
# 495 2025-07-28  70.60  71.00  69.60  70.20   9577988
# 496 2025-07-29  70.20  70.20  66.40  66.60  18369536
# 497 2025-07-30  67.50  67.90  66.10  67.10  13167433
# 498 2025-07-31  67.20  67.80  65.20  65.30  14558661
# 499 2025-08-01  65.40  66.70  65.20  65.20   8232595
#
# [500 rows x 6 columns]

# %%
#time series
df['close'].viz.timeseries(figsize=(10, 6),
		title='Giá đóng cửa - Hợp đồng tương lai ' + ticker,
		ylabel='Giá',
		xlabel='Thời gian',
		color_palette='vnstock',
		palette_shuffle=True)
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Giá đóng cửa - Hợp đồng tương lai MWG'}, xlabel='Thời gian', ylabel='Giá'>)

# %%
#Combo chart
df.viz.combo(bar_data='volume',
             line_data='close',
             title='Giá đóng cửa và khối lượng giao dịch - Hợp đồng tương lai ' +ticker,
             left_ylabel='Volume (M)', right_ylabel='Price (K)',
             figsize=(10, 6),
             color_palette='stock',
             palette_shuffle=True)
# Out:
# (<Figure size 1000x600 with 2 Axes>,
#  <Axes: title={'center': 'Giá đóng cửa và khối lượng giao dịch - Hợp đồng tương lai MWG'}, ylabel='Volume (M)'>,
#  <Axes: title={'center': 'Giá đóng cửa và khối lượng giao dịch - Hợp đồng tương lai MWG'}, ylabel='Price (K)'>)

# %%
#Barplot
income_df[['LN trước thuế', 'Lợi nhuận thuần']].div(1000_000_000)\
    .viz.bar(figsize=(10, 6), 
             title='VCI - Lợi nhuận trước thuế & lợi nhuận thuần (tỷ đồng)', 
             ylabel='Lợi nhuận (tỷ đồng)', 
             xlabel='Năm', 
             color_palette='stock',
             data_labels=True, # Hiển thị giá trị trên cột
             show_legend=True,
             rot=45) # Xoay nhãn trục x 45 độ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[211], line 2
#       1 #Barplot
# ----> 2 income_df[['LN trước thuế', 'Lợi nhuận thuần']].div(1000_000_000)\
#       3     .viz.bar(figsize=(10, 6),
#       4              title='VCI - Lợi nhuận trước thuế & lợi nhuận thuần (tỷ đồng)',
#       5              ylabel='Lợi nhuận (tỷ đồng)',
#       6              xlabel='Năm',
#       7              color_palette='stock',
#       8              data_labels=True, # Hiển thị giá trị trên cột
#       9              show_legend=True,
#      10              rot=45) # Xoay nhãn trục x 45 độ
#
# NameError: name 'income_df' is not defined

# %%
#Heatmap
import pandas as pd
return_pivot = pd.pivot_table(df, index=df.index.year, columns=df.index.month, values='returns', aggfunc='mean')
cmap = df.viz.create_cmap('percentage') # Tạo colormap bằng 1 bảng màu có trong vnstock_ezchart
return_pivot.viz.heatmap(figsize=(10, 6),
                         title='VN30F1M - Thống kê lợi nhuận trung bình theo ngày qua các tháng trong năm (%)',
                         annot=True,
                         cmap=cmap)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[212], line 3
#       1 #Heatmap
#       2 import pandas as pd
# ----> 3 return_pivot = pd.pivot_table(df, index=df.index.year, columns=df.index.month, values='returns', aggfunc='mean')
#       4 cmap = df.viz.create_cmap('percentage') # Tạo colormap bằng 1 bảng màu có trong vnstock_ezchart
#       5 return_pivot.viz.heatmap(figsize=(10, 6),
#       6                          title='VN30F1M - Thống kê lợi nhuận trung bình theo ngày qua các tháng trong năm (%)',
#       7                          annot=True,
#       8                          cmap=cmap)
#
# AttributeError: 'RangeIndex' object has no attribute 'year'

# %%
#Table
df.reset_index().iloc[:10, :5]\
    .viz.table(figsize=(10, 10),
               title='10 dòng đầu tiên của dữ liệu',
               title_loc='center')

# %%
#Histogram
df['returns'].viz.hist(bins=20,
                       figsize=(10, 6),
                       title='VN30F1M - Phân phối lợi nhuận ngày (%)',
                       xlabel='Lợi nhuận (%)',
                       ylabel='Tần suất',
                       color_palette='stock')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\phuongnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'returns'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[214], line 2
#       1 #Histogram
# ...

# %%
#Boxplot
df.volume.div(1000_000)\
    .viz.boxplot(
        title='Phân phối khối lượng giao dịch của ' +ticker, 
        xlabel='', 
        ylabel='KLGD (Triệu CP)', 
        color_palette='stock', 
        palette_shuffle=True,
        figsize=(10, 6))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Phân phối khối lượng giao dịch của MWG'}, ylabel='KLGD (Triệu CP)'>)

# %%
#Word Cloud 
profile_df.viz.wordcloud(figsize=(10, 6), 
                         title='VCB - Mô tả công ty',
                         max_words=50,
                         color_palette='stock')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[216], line 2
#       1 #Word Cloud
# ----> 2 profile_df.viz.wordcloud(figsize=(10, 6),
#       3                          title='VCB - Mô tả công ty',
#       4                          max_words=50,
#       5                          color_palette='stock')
#
# NameError: name 'profile_df' is not defined

# %%
#Pie
shareholders_df.viz.pie(title='Cổ đông lớn VNM',
                                             labels='share_holder',
                                             values='share_own_percent',
                                             figsize=(10, 6),
                                             ylabel='',
                                             color_palette='stock')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[217], line 2
#       1 #Pie
# ----> 2 shareholders_df.viz.pie(title='Cổ đông lớn VNM',
#       3                                              labels='share_holder',
#       4                                              values='share_own_percent',
#       5                                              figsize=(10, 6),
#       6                                              ylabel='',
#       7                                              color_palette='stock')
#
# NameError: name 'shareholders_df' is not defined

# %%
#Treemap
shareholders_df.viz.treemap(title='Cổ đông lớn VNM',

labels='share_holder',

values='share_own_percent',

figsize=(10, 6),

color_palette='stock')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[218], line 2
#       1 #Treemap
# ----> 2 shareholders_df.viz.treemap(title='Cổ đông lớn VNM',
#       3
#       4 labels='share_holder',
#       5
#       6 values='share_own_percent',
#       7
#       8 figsize=(10, 6),
#       9
#      10 color_palette='stock')
#
# NameError: name 'shareholders_df' is not defined

# %%
#Scatter Plot
df.viz.scatter(x='close', y='volume',
               title='VN30F1M - Tương quan giá đóng cửa và khối lượng giao dịch',
               xlabel='Giá đóng cửa',
               ylabel='Khối lượng giao dịch',
               figsize=(10, 6),
               color_palette='stock')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'VN30F1M - Tương quan giá đóng cửa và khối lượng giao dịch'}, xlabel='Giá đóng cửa', ylabel='Khối lượng giao dịch'>)

# %%
#Pairplot
df.viz.pairplot()

# %%
####################################################################################################################################################################################################################################################################
